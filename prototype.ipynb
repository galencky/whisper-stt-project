# %%
# 🛠️ One-time setup
#!pip install -q --upgrade openai-whisper tqdm

# %%
import datetime, shutil, sys
from pathlib import Path
from tqdm import tqdm
import whisper
import time

# === Path configuration (edit BASE_DIR if you like) ===
BASE_DIR        = Path(r"C:/Users/galen/Downloads/whisper-stt-project")
INBOX_DIR       = BASE_DIR / "inbox"
PROCESSED_DIR   = BASE_DIR / "processed"
TRANSCRIPTS_DIR = BASE_DIR / "transcripts"
MODEL_CACHE_DIR = BASE_DIR / "models"

AUDIO_EXT = {'.wav', '.mp3', '.m4a', '.flac', '.ogg', '.webm'}

# Create folders if they don’t exist
for d in (INBOX_DIR, PROCESSED_DIR, TRANSCRIPTS_DIR, MODEL_CACHE_DIR):
    d.mkdir(parents=True, exist_ok=True)

print("✅ Folder structure ready")

def _now():
    """Log-friendly timestamp."""
    return datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def _fmt_ts(seconds: float) -> str:
    """float seconds → HH:MM:SS.mmm string."""
    h, m = divmod(int(seconds), 3600)
    m, s = divmod(m, 60)
    ms   = int((seconds - int(seconds)) * 1000)
    return f"{h:02d}:{m:02d}:{s:02d}.{ms:03d}"

def save_transcript(result: dict, out_path: Path):
    """
    Write Whisper's segment list to a .txt file.
    Each line: [start → end] text
    """
    with open(out_path, "w", encoding="utf-8") as f:
        for seg in result["segments"]:
            f.write(f"[{_fmt_ts(seg['start'])} → {_fmt_ts(seg['end'])}] "
                    f"{seg['text'].strip()}\n")


start = time.time()
print(f"[{_now()}] Loading Whisper large-v3 …")
model = whisper.load_model("large-v3", download_root=str(MODEL_CACHE_DIR))
print(f"[{_now()}] Model ready (took {time.time() - start:.1f} s)\n")
# Out:
# ✅ Folder structure ready
# [2025-05-28 03:57:16] Loading Whisper large-v3 …
# [2025-05-28 03:57:28] Model ready (took 11.8 s)

# %%
# 👇 Set to "zh", "en", "ja", etc. or keep None for auto-detect
PREFERRED_LANGUAGE = "zh"

if PREFERRED_LANGUAGE:
    print(f"🌐 Preferred language set to '{PREFERRED_LANGUAGE}'")
else:
    print("🌐 Using Whisper's automatic language detection")
# Out:
# 🌐 Preferred language set to 'zh'

# %%
audio_files = [p for p in INBOX_DIR.iterdir()
               if p.suffix.lower() in AUDIO_EXT]
total = len(audio_files)

if total == 0:
    print("📂 No audio in inbox. Drop files there and re-run this cell.")
    sys.exit()

for idx, audio in enumerate(audio_files, 1):
    print(f"\n[{_now()}] ▶️  ({idx}/{total})  {audio.name}")

    # --- build kwargs ---
    kwargs = dict(word_timestamps=True, verbose=True)  # verbose prints segments live
    if PREFERRED_LANGUAGE:
        kwargs["language"] = PREFERRED_LANGUAGE
        print(f"[{_now()}] 🔧 Forcing language = '{PREFERRED_LANGUAGE}'")
    else:
        print(f"[{_now()}] 🔍 Auto language detection")

    # --- transcribe (prints out as it goes) ---
    result = model.transcribe(str(audio), **kwargs)

    # --- save & move ---
    out_txt = TRANSCRIPTS_DIR / f"{audio.stem}.txt"
    save_transcript(result, out_txt)
    print(f"[{_now()}] 📝 Saved transcript → {out_txt.name}")

    shutil.move(str(audio), PROCESSED_DIR / audio.name)
    print(f"[{_now()}] ✔️ Moved audio to processed/")

print("\n🎉 All files done!")
# Out:
# [2025-05-28 03:57:28] ▶️  (1/3)  20240927 新生出遊分享.m4a
# [2025-05-28 03:57:28] 🔧 Forcing language = 'zh'
# c:\Users\galen\AppData\Local\Programs\Python\Python311\Lib\site-packages\whisper\transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# [00
# [21:12.660 --> 21:13.980] 就是他也是陽明星光來的
# [21:13.980 --> 21:16.460] 然後他就是對道路交通
# [21:16.460 --> 21:18.200] 我非常高深的理解
# [21:18.200 --> 21:20.740] 然後對然後結果到最後
# [21:20.740 --> 21:22.240] 他就跟我講說欸你知道嗎
# [21:22.240 --> 21:23.800] 我覺得台灣有個交通道很爛
# [21:23.800 --> 21:25.120] 他的設計一定要改一下
# [21:25.120 --> 21:27.360] 可是他不知道要怎麼找這些資料
# [21:27.360 --> 21:31.580] 因為交通路的那個開放的資料太爛了
# [21:31.580 --> 21:32.920] 就那個API很爛
# [21:32.920 --> 21:33.760] 然後結果我就
# [21:33.760 --> 21:35.260] 我就真的就是陪他
# [21:35.260 --> 21:36.700] 我就寫了程式
# [21:36.700 --> 21:38.080] 然後然後寫了程式
# [21:38.080 --> 21:41.340] 然後就是把台灣高速公路的系統的
# [21:41.340 --> 21:43.460] 就是所有車輛感染性資料都挖出來
# [21:43.460 --> 21:46.060] 然後他就寫了一封報告送去交通部門
# [21:46.060 --> 21:47.100] 然後最近交通部門說
# [21:47.100 --> 21:48.360] 欸他們改進這個問題
# [21:48.360 --> 21:49.680] 所以好像我們交得到
# [21:49.680 --> 21:51.640] 因為這件事就是重新設計一下這樣子
# [21:51.640 --> 21:54.040] 就是我發現說好像
# [21:54.040 --> 21:56.300] 好像我就算當一個醫生
# [21:56.300 --> 21:57.560] 我還是也可以做一些就是
# [21:57.560 --> 22:00.220] 就是我可以同時
# [22:00.220 --> 22:01.700] 在擁有醫學知識的時候
# [22:01.700 --> 22:03.300] 用我已經學到的醫學知識
# [22:03.300 --> 22:06.220] 去更親近的一個完成
# [22:06.220 --> 22:08.060] 我以前就是想走二樓的
# [22:08.080 --> 22:09.120] 去做一個二類組的小做的事情
# [22:11.680 --> 22:13.580] 然後對每天是有它的美意
# [22:13.580 --> 22:15.640] 就是我現在有一個事要就是修電腦
# [22:15.640 --> 22:17.280] 然後我就很喜歡去找
# [22:17.280 --> 22:18.820] 就是別人破爛標的電腦
# [22:18.820 --> 22:19.580] 然後把它修好
# [22:19.580 --> 22:20.980] 然後結果有一天就是我不知道
# [22:20.980 --> 22:22.640] 大家都知道基督教論壇報
# [22:23.160 --> 22:25.060] 就是基督教論壇報的小編
# [22:25.060 --> 22:27.260] 他有一台很特別的很特別的Mac
# [22:27.260 --> 22:29.920] 就是很舊就是小小台MacBook Air
# [22:30.320 --> 22:32.320] 然後他那台MacBook Air壞掉了
# [22:32.320 --> 22:33.940] 然後結果就這麼巧
# [22:33.940 --> 22:34.980] 就看到這個現動
# [22:34.980 --> 22:36.920] 更巧的是兩天前
# [22:36.920 --> 22:38.400] 我在垃圾桶撿到了一台
# [22:38.400 --> 22:39.340] 然後把它修好了
# [22:39.920 --> 22:40.900] 所以我就直接把那台
# [22:40.900 --> 22:42.900] 它原本但是壞掉的電腦
# [22:42.900 --> 22:44.740] 我剛好有一台一模一樣的
# [22:44.740 --> 22:46.060] 我就直接把它寄過去給他
# [22:46.060 --> 22:48.040] 所以他就無縫接軌
# [25:59.260 --> 26:00.600] 面試得非常非常的順利
# [26:00.600 --> 26:03.960] 然後我就沒有被問任何跟醫學有關的問題
# [26:03.980 --> 26:06.620] 都在問就是關於我自己的問題
# [26:07.820 --> 26:09.900] 然後所以我現在半夜病人傳起來
# [26:09.900 --> 26:10.900] 我其實還是會很怕
# [26:10.900 --> 26:11.460] 因為好吧
# [26:11.460 --> 26:13.320] 就是上帝用各種方式讓我學會
# [26:13.320 --> 26:15.700] 所以我之前就遇到半夜病人就真的傳起來了
# [26:15.700 --> 26:17.920] 所以就是那個面試的時候沒被問到
# [26:17.920 --> 26:19.460] 但是實際上值班就遇到這樣子
# [26:19.980 --> 26:20.160] 對
# [26:21.040 --> 26:21.980] 好 現在這樣
# [26:23.200 --> 26:24.920] 好 就是我就
# [26:25.640 --> 26:27.300] 所以我就用了短短的時間
# [26:27.300 --> 26:29.640] 就一點時間跟大家講一下就是
# [26:30.060 --> 26:31.520] 自我價值的部分就是
# [26:31.520 --> 26:32.980] 我真的覺得我
# [26:32.980 --> 26:33.700] 就真的講
# [26:33.980 --> 26:34.860] 就是我不配在這邊
# [26:34.860 --> 26:35.820] 就跟大家說叫做
# [26:35.820 --> 26:36.900] 自我價值就是成人
# [26:36.900 --> 26:38.300] 然後最後才可以發揮自我價值
# [26:38.300 --> 26:40.400] 然後才可以讓自己覺得自己很棒的
# [26:40.400 --> 26:42.200] 就我真的覺得我不配為你辦法
# [26:42.200 --> 26:43.900] 所以我整個就是跟大家
# [26:43.900 --> 26:45.440] 簡短的分享一下我的故事
# [26:45.440 --> 26:47.000] 然後就是想讓你知道說就是
# [26:47.420 --> 26:49.540] 上帝對每一個人的人生都是有他的安排
# [26:49.540 --> 26:51.820] 然後會用一些讓你最想不到
# [26:51.820 --> 26:55.300] 但是最讓你印象深刻又驚豔的方式
# [26:55.620 --> 26:57.260] 讓你感受到他的存在
# [26:57.260 --> 26:58.360] 還有他的美好這樣子
# [26:58.800 --> 26:59.640] 所以我想說的是
# [26:59.640 --> 27:01.220] 第一個就是上大學之後呢
# [27:01.220 --> 27:03.540] 就再也沒有什麼成績好就好棒棒之為之
# [27:03.540 --> 27:06.040] 就是你們在考完學測或指考或分科
# [27:06.040 --> 27:08.200] 或whatever現在叫什麼考試之後
# [27:08.200 --> 27:10.560] 就是就再也不會有一個人
# [27:10.560 --> 27:12.060] 認為分數高就比較好
# [27:12.060 --> 27:14.860] 就從現在開始就是已經再也沒有一個考試
# [27:14.860 --> 27:16.220] 會一起的評量所有人
# [27:16.220 --> 27:19.780] 然後直接根據你的成績定義你到底是好還是不好
# [27:19.780 --> 27:24.180] 所以就是台灣人有個問題就是我們很
# [27:24.180 --> 27:26.020] 應該說東亞人好像都這樣
# [27:26.020 --> 27:27.980] 就是我們很喜歡把我們自我價值
# [27:27.980 --> 27:30.560] 會有一段時間建立在我們自己的學術成就上
# [27:30.560 --> 27:32.780] 然後我知道在場一定很多人就是小時候
# [27:32.780 --> 27:34.180] 學術成就應該是還不錯
# [27:34.780 --> 27:36.680] 但是之後就是可能會遇到一些
# [06:22.460 --> 06:26.580] 然後也會對於他特殊的興趣高度的專注
# [06:27.980 --> 06:30.640] 然後對於感官就是可能是視聽秀未出
# [06:30.640 --> 06:32.760] 會特別的敏感或特別的不敏感
# [06:33.520 --> 06:35.780] 那最後就是我剛才講的這些東西
# [06:35.780 --> 06:36.880] 我只是很快速的講
# [06:36.880 --> 06:38.940] 那這些guideline criteria
# [06:38.940 --> 06:40.960] 大家有興趣可以回去自己讀這樣子
# [06:42.160 --> 06:44.820] 然後criteria C就是說
# [06:44.820 --> 06:45.940] 這個必須要
# [06:45.940 --> 06:48.420] 我剛才講的就是要在相對年輕
# [06:48.420 --> 06:52.440] 就是在可能是出生之後可能是幼兒
# [06:52.440 --> 06:57.000] 或者是學就是孩童時期要被發現
# [06:57.980 --> 06:59.360] 然後criteria D就是
# [06:59.360 --> 07:05.620] 這些特質必須要嚴重到對他的生活有實際的影響
# [07:06.260 --> 07:08.360] 所以如果一個人你覺得他看起來就是
# [07:08.980 --> 07:09.940] 以前會看起來啞食
# [07:09.940 --> 07:11.760] 或現在看起來像是有自閉症、不避震
# [07:11.760 --> 07:13.380] 可是他的生活都很OK
# [07:13.380 --> 07:15.980] 那你要說他有問題嗎
# [07:15.980 --> 07:16.580] 好像也不是
# [07:17.020 --> 07:19.720] 然後這些criteria E就是我剛才講的這些東西
# [07:19.720 --> 07:23.320] 不能用就是自閉障礙還有就是發展
# [07:23.740 --> 07:26.500] 比較遲緩的發展里程碑來解釋
# [07:28.220 --> 07:29.880] 你就覺得他可能跟人互動很怪
# [07:29.880 --> 07:31.320] 但他其實就只是發展遲緩
# [07:31.320 --> 07:32.680] 不能說他自閉症、不避震
# [07:32.680 --> 07:34.880] 所以我剛才講的應該都合理吧
# [07:35.360 --> 07:35.680] 好
# [07:35.680 --> 07:37.380] 那接下來就是推薦毒物
# [07:37.380 --> 07:38.740] 對就是這個
# [07:39.860 --> 07:41.080] 很推薦大家去看
# [07:41.080 --> 07:43.820] 就是這算是我自己少數
# [07:43.820 --> 07:46.440] 它其實就是貓咪寫真集
# [07:46.440 --> 07:48.780] 然後用貓咪寫真集在描述說
# [07:48.780 --> 07:52.240] 就是為什麼就是所有的貓咪都在
# [07:52.240 --> 07:55.200] 就是以前叫做為什麼所有的貓咪都有亞斯伯格症
# [07:55.200 --> 07:57.060] 然後變成自閉症、不避震障礙就是變成
# [07:57.060 --> 07:57.960] 為什麼所有的貓咪都在
# [07:57.980 --> 07:59.740] 自閉症的光譜上
# [08:00.240 --> 08:03.040] 然後這是極少數讓我會看到哭的書這樣子
# [08:03.040 --> 08:03.740] 好
# [08:04.560 --> 08:05.760] 然後影集的話
# [08:05.760 --> 08:07.020] 這是一個我的名字叫可漢
# [08:07.020 --> 08:09.680] 就是在講九一事件的一段時間
# [08:09.680 --> 08:11.200] 就是穆斯林受歧視的故事
# [08:11.200 --> 08:13.300] 但是這個主角他把就是
# [08:13.300 --> 08:15.880] 以前叫亞斯伯格症的人就是演得很像
# [08:15.880 --> 08:17.660] 然後這就是非常律師
# [44:31.420 --> 44:33.880] 如果是為了省錢自己開車的話
# [44:33.880 --> 44:35.580] 我覺得一個不小心騎
# [44:36.420 --> 44:36.840] 就很麻煩
# [44:36.840 --> 44:39.740] 所以我覺得如果光線不好
# [44:39.740 --> 44:41.820] 或是你很累就直接不要開車回來
# [44:42.420 --> 44:43.360] 我真的覺得不要
# [44:43.360 --> 44:46.000] 因為這次陪有可能爸爸其實這一季
# [44:46.000 --> 44:48.460] 都叫計程車也不會要付那麼大的代價
# [44:48.460 --> 44:49.180] 幾萬塊
# [44:49.180 --> 44:51.480] 叫計程車可以用好久
# [44:51.480 --> 44:53.440] 你說來回算五百對不對
# [44:54.180 --> 44:56.160] 那幾萬塊去取五百
# [44:56.160 --> 44:57.660] 你可以幾次叫計程車
# [44:57.660 --> 44:59.060] 也不會有冒風險說
# [44:59.060 --> 45:01.000] 這次是因為都沒撞到人喔
# [45:01.000 --> 45:03.160] 或是沒有碰到人只是車子
# [45:03.160 --> 45:06.400] 是小事但是我就擔心說在路上
# [45:06.420 --> 45:08.200] 有不小心去碰撞到別人
# [45:08.200 --> 45:09.500] 是吃不完的都是這樣
# [45:09.500 --> 45:12.200] 我覺得你們真的就是要
# [45:12.200 --> 45:14.040] 想辦法就是要
# [45:14.040 --> 45:15.560] 好好利用現在
# [45:15.560 --> 45:17.860] 現在我們這個家有的
# [45:18.420 --> 45:19.760] 資本跟金錢
# [45:19.760 --> 45:22.140] 然後就是要想辦法讓減少自己
# [45:22.140 --> 45:24.340] 平常生活中的負擔
# [45:24.340 --> 45:25.520] 跟生活中的
# [45:26.260 --> 45:27.060] 煩惱
# [45:28.540 --> 45:29.660] 謝謝你啊
# [45:29.660 --> 45:31.820] 不然這樣真的活起來很辛苦耶
# [45:31.820 --> 45:32.100] 我覺得
# [45:33.140 --> 45:33.820] 謝謝你
# [45:36.420 --> 45:37.360] 等到我六十幾歲
# [45:37.360 --> 45:39.320] 我的願望就是
# [45:39.320 --> 45:40.780] 我就是要財富自由
# [45:40.780 --> 45:44.100] 身體健康到處出國玩
# [45:44.100 --> 45:45.380] 我什麼事情都不想管
# [45:46.640 --> 45:47.600] 我就覺得
# [45:48.940 --> 45:50.460] 真的要好好想想
# [45:50.460 --> 45:52.140] 怎麼讓自己的生活活得
# [45:52.140 --> 45:52.960] 不要那麼痛苦
# [45:52.960 --> 45:55.780] 因為你知道
# [45:55.780 --> 45:56.780] 當我看到就是
# [45:56.780 --> 45:59.400] 跟我同年齡的人
# [45:59.400 --> 46:01.640] 他們的爸媽幾乎都是退休
# [46:01.640 --> 46:03.140] 整天遊山玩水
# [46:03.140 --> 46:04.880] 然後基本上就是把
# [46:06.680 --> 46:08.420] 自己的財產都處理好
# [46:08.420 --> 46:11.240] 或是之後退休的規劃都做好
# [46:11.240 --> 46:12.280] 就發現我們家好像還是
# [46:12.280 --> 46:13.180] 跟十年前一樣
# [46:13.180 --> 46:14.580] 就覺得好像那裡怪怪的
# [46:14.580 --> 46:16.820] 所以我才會拿出來講
# [46:16.820 --> 46:20.020] 因為好像我覺得說
# [51:57.880 --> 51:59.220] 時間跟睡眠喔
# [51:59.780 --> 52:01.140] 不是因為想用什麼
# [52:01.140 --> 52:02.880] 而犧牲睡眠了
# [52:02.880 --> 52:05.240] 然後做太多的事情
# [52:05.240 --> 52:06.400] 讓自己常常很忙
# [52:06.400 --> 52:06.400] 所以我希望
# [52:07.520 --> 52:09.640] 現在還沒什麼想法
# [52:09.640 --> 52:11.000] 然後媽媽
# [52:11.000 --> 52:11.900] 媽媽跟你提出
# [52:11.900 --> 52:13.740] 因為你是女孩子住在外面
# [52:13.740 --> 52:15.480] 可能時間點
# [52:15.480 --> 52:16.740] 我不知道冠元大學生
# [52:16.740 --> 52:19.140] 你覺得會起點比較合宜
# [52:19.140 --> 52:21.740] 就是回去的時間常常好晚
# [52:21.740 --> 52:23.480] 我也不知道台北那邊是不是安全
# [52:23.480 --> 52:24.880] 我都會掛心耶
# [52:24.880 --> 52:27.200] 台北其實算蠻安全的地方
# [52:27.200 --> 52:29.020] 對但是自己一個人走的時候
# [52:29.020 --> 52:32.660] 起點以前是比較正常OK的狀態
# [52:32.660 --> 52:35.220] 要回到宿舍是保護自己
# [52:35.220 --> 52:36.380] 因為越晚的時候
# [52:36.400 --> 52:37.500] 越難遇到怪怪人
# [52:37.500 --> 52:39.660] 我覺得作為一個
# [52:39.660 --> 52:41.880] 要對自己負責的成年人
# [52:41.880 --> 52:43.860] 其實你就是每一天你自己決定
# [52:43.860 --> 52:44.880] 你什麼時候要回家
# [52:46.120 --> 52:47.840] 這沒有標準答案
# [52:48.400 --> 52:49.960] 可是當時間到自己有一個
# [52:49.960 --> 52:51.980] 一個留意這樣子
# [52:52.660 --> 52:53.300] 我有時候
# [52:53.300 --> 52:56.180] 我念大學的時候有時候凌晨三點
# [52:56.180 --> 52:57.740] 我在睡覺有時候凌晨三點
# [52:57.740 --> 52:59.640] 我漫無目的地走在街上
# [52:59.640 --> 53:00.960] 所以我覺得這沒有一個標準答案
# [53:00.960 --> 53:02.900] 給自己一個風險就對了
# [53:03.660 --> 53:05.240] 因為如果遇到一些
# [53:06.400 --> 53:08.060] 怪怪人漂流在街上拿一把刀
# [53:08.060 --> 53:09.260] 那時候周圍也沒人
# [53:09.260 --> 53:11.260] 我講的是太離譜的一個
# [53:11.260 --> 53:12.880] 就是說怎麼樣讓自己
# [53:12.880 --> 53:16.120] 不讓自己處在一個
# [53:16.120 --> 53:18.520] 危險狀態是可以避免的
# [53:18.520 --> 53:20.480] 就像我們撐著傘我們不會淋到雨
# [53:20.480 --> 53:21.140] 你故意要
# [53:21.660 --> 53:24.180] 散離得遠遠的然後讓自己去淋雨
# [53:24.180 --> 53:26.000] 也是可以但是就是
# [53:26.000 --> 53:28.180] 有傘撐的時候你是一個保護
# [53:28.180 --> 53:29.160] 不會淋死自己
# [53:29.160 --> 53:31.960] 那個傘我是比喻說一個時間範圍內
# [53:31.960 --> 53:33.660] 是讓自己比較安全
# [53:35.340 --> 53:35.780] 可以
# [53:41.960 --> 53:43.300] 然後哥哥你是
# [53:43.300 --> 53:45.220] 你是妹妹的哥哥
# [57:53.160 --> 57:54.040] 阿們
# [57:54.860 --> 57:55.380] OK
# [57:55.380 --> 57:56.700] 謝謝你們
# [57:58.140 --> 58:00.160] 想抱抱你們每一個人
# [58:00.160 --> 58:00.880] 就請阿們
# [2025-05-28 09:26:12] 📝 Saved transcript → 20250131 在家分享.txt
# [2025-05-28 09:26:12] ✔️ Moved audio to processed/
#
# 🎉 All files done!

# %%
import re
from datetime import timedelta
from pathlib import Path

# Set BASE_DIR and folders
BASE_DIR = Path(r"C:/Users/galen/Downloads/whisper-stt-project")
transcripts_dir = BASE_DIR / "transcripts"
parsed_dir = BASE_DIR / "parsed"
parsed_dir.mkdir(exist_ok=True)

# Regex pattern
timestamp_pattern = re.compile(
    r"\[(\d{2}:\d{2}:\d{2}\.\d{3})\s*→\s*(\d{2}:\d{2}:\d{2}\.\d{3})\]\s*(.*)"
)

def parse_time(s):
    h, m, rest = s.split(":")
    s, ms = rest.split(".")
    return timedelta(hours=int(h), minutes=int(m), seconds=int(s), milliseconds=int(ms))

def process_transcript(text):
    lines = text.splitlines()
    segments = []
    for line in lines:
        m = timestamp_pattern.match(line)
        if m:
            start_ts, end_ts, content = m.groups()
            segments.append((parse_time(start_ts), start_ts, content.strip()))
    if not segments:
        return ""  # No matches found

    result = []
    buffer = ""
    last_mark_minute = None

    for ts, start_ts_str, content in segments:
        curr_minute = int(ts.total_seconds() // 300)  # every 5 minutes (300 sec)
        if last_mark_minute is None or curr_minute != last_mark_minute:
            if buffer:
                result.append(buffer.strip())
                buffer = ""
            result.append(f"[{start_ts_str}]")
            last_mark_minute = curr_minute
        buffer += content + " "
    if buffer:
        result.append(buffer.strip())

    # Group as: [timestamp]\n<text>\n\n
    output = []
    for i in range(0, len(result), 2):
        if i + 1 < len(result):
            output.append(result[i])         # timestamp
            output.append(result[i+1])       # paragraph
            output.append("")                # blank line
        else:
            output.append(result[i])
    return "\n".join(output).strip()

# ---- Batch processing ----
for txtfile in transcripts_dir.glob("*.txt"):
    with txtfile.open(encoding="utf-8") as f:
        text = f.read()
    processed = process_transcript(text)
    out_path = parsed_dir / txtfile.name.replace(".txt", "_parsed.txt")
    with out_path.open("w", encoding="utf-8") as f:
        f.write(processed)
    print(f"Processed {txtfile.name} -> {out_path.name}")
# Out:
# Processed 20240927 新生出遊分享.txt -> 20240927 新生出遊分享_parsed.txt
# Processed 20241124 ASD分享.txt -> 20241124 ASD分享_parsed.txt
# Processed 20250131 在家分享.txt -> 20250131 在家分享_parsed.txt
# Processed 20250519 MedEdBot 發表.txt -> 20250519 MedEdBot 發表_parsed.txt
# Processed 20250521 社醫 醫師公會.txt -> 20250521 社醫 醫師公會_parsed.txt
# Processed 錄製 (5).txt -> 錄製 (5)_parsed.txt

# %%
SYSTEM_PROMPT = """
## System Prompt

You are tasked with summarizing a speech provided in its original language. Create a concise, structured summary using clear and informative markdown formatting. Follow the outline and format precisely. You may use markdown tables, bullet points, paragraphs, or a combination as appropriate.

## Summary Structure

### Title

Provide a concise, relevant title reflecting the key theme or message of the speech.
Please make sure the title starts with a # to be recognized as title.

# Title

### Speaker

* **Name**: \\[Speaker's Name]
* **Affiliation/Role**: \\[Speaker’s Affiliation or Role, if known]
* **Event**: \\[Event or occasion where the speech was given, if applicable]
* **Date**: \\[Date of the speech, if available]

### Overview

Provide a short paragraph summarizing the overall purpose and main points of the speech.

### Key Points

Summarize each major point clearly. You may use markdown tables, bullet points, or paragraphs as needed:

* **Key Point 1**: Brief description with supporting details.
* **Key Point 2**: Brief description with supporting details.
* Additional points as necessary.

Or alternatively, use a markdown table.

### Notable Quotes

Include one or two significant quotes from the speech, if available, highlighting central themes or key statements made by the speaker:

* *"Quote 1..."*
* *"Quote 2..."*

### Audience Reaction

Briefly describe audience reactions, if mentioned or apparent (e.g., applause, questions raised, notable silence).

### Conclusion

Summarize briefly how the speaker concluded their speech and highlight any key takeaway messages.

---

Ensure clarity, accuracy, and conciseness in the summary, preserving essential context and meaning.
Please summarize using the native language of the speech.

"""

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
import google.generativeai as genai

# Load .env from BASE_DIR
BASE_DIR = Path(r"C:/Users/galen/Downloads/whisper-stt-project")
load_dotenv(dotenv_path=BASE_DIR / ".env")
api_key = os.environ.get("GEMINI_API_KEY")
if not api_key:
    raise ValueError("GEMINI_API_KEY not found in .env file!")

# Configure Gemini API
genai.configure(api_key=api_key)

PARSED_DIR = BASE_DIR / "parsed"
MARKDOWN_DIR = BASE_DIR / "markdown"

def generate_summary_with_gemini(speech_text, system_prompt):
    model = genai.GenerativeModel("gemini-2.5-flash-preview-05-20")
    full_prompt = system_prompt.strip() + "\n\n" + speech_text.strip()
    try:
        response = model.generate_content(
            full_prompt,
            generation_config=genai.types.GenerationConfig(
                temperature=0.5,
            ),
            stream=False,
        )
        return response.text
    except Exception as e:
        print(f"[ERROR] Gemini API error: {e}")
        return None

def process_all_txt_files(parsed_dir, markdown_dir, system_prompt):
    parsed_dir = Path(parsed_dir)
    markdown_dir = Path(markdown_dir)
    markdown_dir.mkdir(exist_ok=True)

    txt_files = list(parsed_dir.glob("*.txt"))
    print(f"[DEBUG] Found {len(txt_files)} .txt files in {parsed_dir}")

    for txt_path in txt_files:
        print(f"\n[DEBUG] Processing: {txt_path.name}")

        try:
            with open(txt_path, "r", encoding="utf-8") as f:
                speech_text = f.read().strip()
        except Exception as e:
            print(f"[ERROR] Could not read {txt_path}: {e}")
            continue

        if not speech_text:
            print(f"[WARNING] {txt_path.name} is empty, skipping.")
            continue

        summary_md = generate_summary_with_gemini(speech_text, system_prompt)
        if summary_md is None:
            print(f"[ERROR] Gemini API failed for {txt_path.name}, skipping.")
            continue

        md_path = markdown_dir / (txt_path.stem + ".md")
        try:
            with open(md_path, "w", encoding="utf-8") as f:
                f.write(summary_md)
            print(f"[INFO] Saved summary to {md_path}")
        except Exception as e:
            print(f"[ERROR] Could not save {md_path}: {e}")

# Run the batch processing
process_all_txt_files(PARSED_DIR, MARKDOWN_DIR, SYSTEM_PROMPT)
# Out:
# [DEBUG] Found 6 .txt files in C:\Users\galen\Downloads\whisper-stt-project\parsed
#
# [DEBUG] Processing: 20240927 新生出遊分享_parsed.txt
# [INFO] Saved summary to C:\Users\galen\Downloads\whisper-stt-project\markdown\20240927 新生出遊分享_parsed.md
#
# [DEBUG] Processing: 20241124 ASD分享_parsed.txt
# [INFO] Saved summary to C:\Users\galen\Downloads\whisper-stt-project\markdown\20241124 ASD分享_parsed.md
#
# [DEBUG] Processing: 20250131 在家分享_parsed.txt
# [INFO] Saved summary to C:\Users\galen\Downloads\whisper-stt-project\markdown\20250131 在家分享_parsed.md
#
# [DEBUG] Processing: 20250519 MedEdBot 發表_parsed.txt
# [INFO] Saved summary to C:\Users\galen\Downloads\whisper-stt-project\markdown\20250519 MedEdBot 發表_parsed.md
#
# [DEBUG] Processing: 20250521 社醫 醫師公會_parsed.txt
# [INFO] Saved summary to C:\Users\galen\Downloads\whisper-stt-project\markdown\20250521 社醫 醫師公會_parsed.md
#
# [DEBUG] Processing: 錄製 (5)_parsed.txt
# [INFO] Saved summary to C:\Users\galen\Downloads\whisper-stt-project\markdown\錄製 (5)_parsed.md

# %%
import os
from pathlib import Path
import shutil
import requests
from dotenv import load_dotenv

# Set your paths
BASE_DIR = Path(r"C:/Users/galen/Downloads/whisper-stt-project")
MARKDOWN_DIR = BASE_DIR / "markdown"
UPLOADED_DIR = BASE_DIR / "uploaded"
UPLOADED_DIR.mkdir(exist_ok=True)

# Load your HackMD API token
load_dotenv(dotenv_path=BASE_DIR / ".env")
hackmd_token = os.environ.get("HACKMD_TOKEN")
if not hackmd_token:
    raise ValueError("HACKMD_TOKEN not found in .env file!")

def upload_to_hackmd(md_content, filename, api_token):
    # Clean up title: remove '_parsed', '.md', and prettify
    if filename.endswith('.md'):
        filename = filename[:-3]
    raw_title = filename.replace('_parsed', '').strip()
    title = raw_title.replace('_', ' ').strip()  # Prettify for heading

    # Remove any initial blank lines
    md_lines = md_content.lstrip().splitlines()

    # If the first non-blank line is a heading, replace with our title; otherwise, insert our title heading
    if not md_lines or not md_lines[0].strip().startswith("# "):
        md_content = f"# {title}\n\n" + md_content.lstrip()
    else:
        md_lines[0] = f"# {title}"
        md_content = "\n".join(md_lines)

    # Add tag hashtag at the end (if not already present as its own line)
    hashtag = "#whisper-stt-project"
    content_lines = md_content.rstrip().splitlines()
    if not any(line.strip() == hashtag for line in content_lines[-3:]):  # Look at last few lines
        md_content = md_content.rstrip() + "\n\n" + hashtag + "\n"

    url = "https://api.hackmd.io/v1/notes"
    headers = {
        "Authorization": f"Bearer {api_token}",
        "Content-Type": "application/json"
    }
    data = {
        "title": title,
        "content": md_content,
        "readPermission": "guest",
        "writePermission": "signed_in"
    }
    response = requests.post(url, headers=headers, json=data)
    if response.ok:
        note_id = response.json().get("id")
        shared_url = f"https://hackmd.io/{note_id}"
        print(f"[INFO] Uploaded to HackMD: {shared_url}")
        return {"title": title, "url": shared_url}
    else:
        print(f"[ERROR] HackMD upload failed for {filename}: {response.status_code} {response.text}")
        return None

def batch_upload_markdown_and_move(markdown_dir, uploaded_dir, hackmd_token):
    markdown_dir = Path(markdown_dir)
    uploaded_dir = Path(uploaded_dir)
    uploaded_dir.mkdir(exist_ok=True)
    md_files = list(markdown_dir.glob("*.md"))
    print(f"[DEBUG] Found {len(md_files)} markdown files to upload.")
    shared_links = []
    for md_file in md_files:
        print(f"[DEBUG] Processing: {md_file.name}")
        try:
            with open(md_file, "r", encoding="utf-8") as f:
                md_content = f.read()
        except Exception as e:
            print(f"[ERROR] Could not read {md_file.name}: {e}")
            continue

        result = upload_to_hackmd(md_content, md_file.name, hackmd_token)
        if result:
            shared_links.append(result)
            dest_file = uploaded_dir / md_file.name
            try:
                shutil.move(str(md_file), dest_file)
                print(f"[INFO] Moved {md_file.name} to {dest_file}")
            except Exception as e:
                print(f"[ERROR] Failed to move {md_file.name}: {e}")
    return shared_links

# Run the batch uploader and collect links
shared_links = batch_upload_markdown_and_move(MARKDOWN_DIR, UPLOADED_DIR, hackmd_token)
# Out:
# [DEBUG] Found 6 markdown files to upload.
# [DEBUG] Processing: 20240927 新生出遊分享_parsed.md
# [INFO] Uploaded to HackMD: https://hackmd.io/lYzqXq9tRomnISSAqQmo_w
# [INFO] Moved 20240927 新生出遊分享_parsed.md to C:\Users\galen\Downloads\whisper-stt-project\uploaded\20240927 新生出遊分享_parsed.md
# [DEBUG] Processing: 20241124 ASD分享_parsed.md
# [INFO] Uploaded to HackMD: https://hackmd.io/PyPkxjj3SvugR7egSMSrYg
# [INFO] Moved 20241124 ASD分享_parsed.md to C:\Users\galen\Downloads\whisper-stt-project\uploaded\20241124 ASD分享_parsed.md
# [DEBUG] Processing: 20250131 在家分享_parsed.md
# [INFO] Uploaded to HackMD: https://hackmd.io/-n8mYvkNQuOQaHfbMiaSyw
# [INFO] Moved 20250131 在家分享_parsed.md to C:\Users\galen\Downloads\whisper-stt-project\uploaded\20250131 在家分享_parsed.md
# [DEBUG] Processing: 20250519 MedEdBot 發表_parsed.md
# [INFO] Uploaded to HackMD: https://hackmd.io/Jgfdb7bISU2jzzRvpCDXAA
# [INFO] Moved 20250519 MedEdBot 發表_parsed.md to C:\Users\galen\Downloads\whisper-stt-project\uploaded\20250519 MedEdBot 發表_parsed.md
# [DEBUG] Processing: 20250521 社醫 醫師公會_parsed.md
# [INFO] Uploaded to HackMD: https://hackmd.io/4vaT_ZAlR622RtQu444O8g
# [INFO] Moved 20250521 社醫 醫師公會_parsed.md to C:\Users\galen\Downloads\whisper-stt-project\uploaded\20250521 社醫 醫師公會_parsed.md
# [DEBUG] Processing: 錄製 (5)_parsed.md
# [INFO] Uploaded to HackMD: https://hackmd.io/8ckJy2diRuG365vFl0OoFQ
# [INFO] Moved 錄製 (5)_parsed.md to C:\Users\galen\Downloads\whisper-stt-project\uploaded\錄製 (5)_parsed.md

# %%
from dotenv import load_dotenv
import os
from pathlib import Path
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.header import Header

# Ensure .env is loaded
BASE_DIR = Path(r"C:/Users/galen/Downloads/whisper-stt-project")
load_dotenv(dotenv_path=BASE_DIR / ".env")

email_user = os.environ.get("EMAIL_USER")
email_pass = os.environ.get("EMAIL_PASS")
email_to = os.environ.get("EMAIL_TO")  # Add this to .env or set manually

if not (email_user and email_pass and email_to):
    raise ValueError("EMAIL_USER, EMAIL_PASS, or EMAIL_TO not found in .env file!")

subject = "📝 Your Uploaded HackMD Speech Summaries"
body_lines = [
    "Hello,",
    "",
    "Your audio files have been automatically transcribed using Whisper AI,",
    "and the speech content was summarized using Gemini Flash 2.5.",
    "",
    "Here are the links to your uploaded speech summaries on HackMD:",
    ""
]

for link in shared_links:
    body_lines.append(f"- {link['title']}: {link['url']}")

body_lines += [
    "",
    "All documents are shared and accessible to anyone with the link.",
    "",
    "If you have any questions or encounter any problems, feel free to reply to this email!",
    "",
    "Best regards,",
    "Whisper-STT-Project Bot"
]

body = "\n".join(body_lines)

# Build the email
msg = MIMEMultipart()
msg['From'] = email_user
msg['To'] = email_to
msg['Subject'] = Header(subject, 'utf-8')
msg.attach(MIMEText(body, 'plain', 'utf-8'))

# Send via SMTP (Gmail SMTP by default)
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as server:
    server.login(email_user, email_pass)
    server.send_message(msg)
    print("[INFO] Email sent successfully.")
# Out:
# [INFO] Email sent successfully.
